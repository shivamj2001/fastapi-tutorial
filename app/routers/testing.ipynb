# %%
d1 = {"A":5,"B":15}
d2 = {"A":10,"B":8,"C":12}

out = {}

for keys in d2:
   if keys in d1:
           out[keys] = max(d1[keys], d2[keys])
   else:
              out[keys] = d2[keys]


out
# Out:
# {'A': 10, 'B': 15, 'C': 12}

# %%
p_list = [1,2,3,6,7,10,11,12,20,25,26,27,28,29]

out = []
mini = []

for val in range(len(p_list)):

    mini.append(p_list[val])
    if (val == len(p_list)-1) or (p_list[val+1] != p_list[val]+1):
        out.append(mini)
        mini = []


out
# Out:
# [[1, 2, 3], [6, 7], [10, 11, 12], [20], [25, 26, 27, 28, 29]]
